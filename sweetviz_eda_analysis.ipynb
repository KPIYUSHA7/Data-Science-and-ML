# %%
import pandas as pd
import sweetviz as sv

# %%
cereal_data = pd.read_csv("cereal.csv")

# %%
cereal_data.head()
# Out:
#                         name mfr type  calories  protein  fat  sodium  fiber  \
# 0                  100% Bran   N    C        70        4    1     130   10.0
# 1          100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                   All-Bran   K    C        70        4    1     260    9.0
# 3  All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4             Almond Delight   R    C       110        2    2     200    1.0
#
#    carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1    8.0       8     135         0      3     1.0  1.00  33.983679
# 2    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    8.0       0     330        25      3     1.0  0.50  93.704912
# 4   14.0       8      -1        25      3     1.0  0.75  34.384843

# %%
cereal_data.describe().transpose()
# Out:
#           count        mean        std        min         25%         50%  \
# calories   77.0  106.883117  19.484119  50.000000  100.000000  110.000000
# protein    77.0    2.545455   1.094790   1.000000    2.000000    3.000000
# fat        77.0    1.012987   1.006473   0.000000    0.000000    1.000000
# sodium     77.0  159.675325  83.832295   0.000000  130.000000  180.000000
# fiber      77.0    2.151948   2.383364   0.000000    1.000000    2.000000
# carbo      77.0   14.597403   4.278956  -1.000000   12.000000   14.000000
# sugars     77.0    6.922078   4.444885  -1.000000    3.000000    7.000000
# potass     77.0   96.077922  71.286813  -1.000000   40.000000   90.000000
# vitamins   77.0   28.246753  22.342523   0.000000   25.000000   25.000000
# shelf      77.0    2.207792   0.832524   1.000000    1.000000    2.000000
# weight     77.0    1.029610   0.150477   0.500000    1.000000    1.000000
# cups       77.0    0.821039   0.232716   0.250000    0.670000    0.750000
# ...

# %%
cereal_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77 entries, 0 to 76
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   name      77 non-null     object
#  1   mfr       77 non-null     object
#  2   type      77 non-null     object
#  3   calories  77 non-null     int64
#  4   protein   77 non-null     int64
#  5   fat       77 non-null     int64
#  6   sodium    77 non-null     int64
#  7   fiber     77 non-null     float64
#  8   carbo     77 non-null     float64
#  9   sugars    77 non-null     int64
#  10  potass    77 non-null     int64
#  11  vitamins  77 non-null     int64
#  12  shelf     77 non-null     int64
#  13  weight    77 non-null     float64
#  14  cups      77 non-null     float64
#  15  rating    77 non-null     float64
# dtypes: float64(5), int64(8), object(3)
# memory usage: 9.8+ KB

# %%
report = sv.analyze(cereal_data)
report.show_html("cereal_data_analysis.html")
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:08  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:00  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
cereal_data.shape
# Out:
# (77, 16)

# %%
#Split into train and test - Just for analysis

train = cereal_data.iloc[1:51, :]
test = cereal_data.iloc[51:, :]

# %%
train
# Out:
#                                       name mfr type  calories  protein  fat  \
# 1                        100% Natural Bran   Q    C       120        3    5
# 2                                 All-Bran   K    C        70        4    1
# 3                All-Bran with Extra Fiber   K    C        50        4    0
# 4                           Almond Delight   R    C       110        2    2
# 5                  Apple Cinnamon Cheerios   G    C       110        2    2
# 6                              Apple Jacks   K    C       110        2    0
# 7                                  Basic 4   G    C       130        3    2
# 8                                Bran Chex   R    C        90        2    1
# 9                              Bran Flakes   P    C        90        3    0
# 10                            Cap'n'Crunch   Q    C       120        1    2
# 11                                Cheerios   G    C       110        6    2
# ...

# %%
test
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 51       Oatmeal Raisin Crisp   G    C       130        3    2     170    1.5
# 52      Post Nat. Raisin Bran   P    C       120        3    1     200    6.0
# 53                 Product 19   K    C       100        3    0     320    1.0
# 54                Puffed Rice   Q    C        50        1    0       0    0.0
# 55               Puffed Wheat   Q    C        50        2    0       0    1.0
# 56         Quaker Oat Squares   Q    C       100        4    1     135    2.0
# 57             Quaker Oatmeal   Q    H       100        5    2       0    2.7
# 58                Raisin Bran   K    C       120        3    1     210    5.0
# 59            Raisin Nut Bran   G    C       100        3    2     140    2.5
# 60             Raisin Squares   K    C        90        2    0       0    2.0
# 61                  Rice Chex   R    C       110        1    0     240    0.0
# ...

# %%
compare_report = sv.compare([train, "Training Data"], [test, "Test Data"], "rating")
compare_report.show_html("compare_train_test.html")
# Out:
#                                    |                         | [  0%]   00:00  -> (? left)
#
#
#
# Summarizing dataframe:             |                         | [  0%]   00:00  -> (? left)
#
#
#
# :TARGET::                          |█▏                   | [  6%]   00:00  -> (00:00 left)
#
#
#
# :TARGET::                          |██▍                  | [ 12%]   00:00  -> (00:06 left)
#
#
#
# :name:                             |██▍                  | [ 12%]   00:00  -> (00:06 left)
#
#
#
# :mfr:                              |███▋                 | [ 18%]   00:00  -> (00:06 left)
#
#
#
# :mfr:                              |████▉                | [ 24%]   00:01  -> (00:05 left)
#
#
#
# :type:                             |████▉                | [ 24%]   00:01  -> (00:05 left)
#
#
#
# :type:                             |██████▏              | [ 29%]   00:02  -> (00:05 left)
#
#
#
# :calories:                         |██████▏              | [ 29%]   00:02  -> (00:05 left)
#
#
#
# ...
